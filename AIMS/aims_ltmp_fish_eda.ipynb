# %% [markdown]
# # AIMS LTMP Fish Occurrence — EDA
#
# This notebook provides a lightweight exploratory analysis of `AIMSdataset/occurrence.txt` (Darwin Core format).

# %%
from pathlib import Path
import os

DATA_PATH = Path(os.getenv('AIMS_DATASET_PATH', 'AIMSdataset/occurrence.txt'))
DATA_PATH
# Out:
# WindowsPath('AIMSdataset/occurrence.txt')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(DATA_PATH, sep='	', low_memory=False)
df['eventDate'] = pd.to_datetime(df['eventDate'], errors='coerce')

df
# Out:
#                                                        id  \
# 0       urn:catalog:AIMS:Fish_LTMP:1c6e5e50-5eba-11e3-...
# 1       urn:catalog:AIMS:Fish_LTMP:76dc8c70-fe46-11e6-...
# 2       urn:catalog:AIMS:Fish_LTMP:0bd73a50-e14f-11e7-...
# 3                      urn:catalog:AIMS:Fish_LTMP:1462916
# 4                      urn:catalog:AIMS:Fish_LTMP:1460742
# ...                                                   ...
# 168615  urn:catalog:AIMS:Fish_LTMP:a98a2430-138f-11e2-...
# 168616                urn:catalog:AIMS:Fish_LTMP:32001123
# 168617                 urn:catalog:AIMS:Fish_LTMP:1818536
# 168618  urn:catalog:AIMS:Fish_LTMP:3053b070-1be4-11e1-...
# 168619                 urn:catalog:AIMS:Fish_LTMP:1666316
#
#                    modified  bibliographicCitation  references  \
# 0       2018-07-12T13:20:21                    NaN         NaN
# 1       2018-07-12T13:20:39                    NaN         NaN
# 2       2018-07-12T13:20:39                    NaN         NaN
# 3       2018-07-12T13:20:48                    NaN         NaN
# 4       2018-07-12T13:20:48                    NaN         NaN
# ...                     ...                    ...         ...
# 168615  2018-07-12T13:42:36                    NaN         NaN
# 168616  2018-07-12T13:28:00                    NaN         NaN
# 168617  2018-07-12T13:27:56                    NaN         NaN
# 168618  2018-07-12T13:43:33                    NaN         NaN
# 168619  2018-07-12T13:30:31                    NaN         NaN
#
#        institutionCode  collectionCode     basisOfRecord  materialSampleID  \
# 0                 AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 1                 AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 2                 AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 3                 AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 4                 AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# ...                ...             ...               ...               ...
# 168615            AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 168616            AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 168617            AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 168618            AIMS  AIMS_LTMP_fish  HumanObservation               NaN
# 168619            AIMS  AIMS_LTMP_fish  HumanObservation               NaN
#
#                                              occurrenceID  \
# 0       urn:catalog:AIMS:Fish_LTMP:1c6e5e50-5eba-11e3-...
# 1       urn:catalog:AIMS:Fish_LTMP:76dc8c70-fe46-11e6-...
# 2       urn:catalog:AIMS:Fish_LTMP:0bd73a50-e14f-11e7-...
# 3                      urn:catalog:AIMS:Fish_LTMP:1462916
# 4                      urn:catalog:AIMS:Fish_LTMP:1460742
# ...                                                   ...
# 168615  urn:catalog:AIMS:Fish_LTMP:a98a2430-138f-11e2-...
# 168616                urn:catalog:AIMS:Fish_LTMP:32001123
# 168617                 urn:catalog:AIMS:Fish_LTMP:1818536
# 168618  urn:catalog:AIMS:Fish_LTMP:3053b070-1be4-11e1-...
# 168619                 urn:catalog:AIMS:Fish_LTMP:1666316
#
#                                catalogNumber  ...    phylum         class  \
# 0       1c6e5e50-5eba-11e3-b198-d4bed94e66aa  ...  Chordata  Osteichthyes
# 1       76dc8c70-fe46-11e6-8a51-d4bed94e66aa  ...  Chordata  Osteichthyes
# 2       0bd73a50-e14f-11e7-aedf-d4bed94e66aa  ...  Chordata  Osteichthyes
# 3                                    1462916  ...  Chordata  Osteichthyes
# 4                                    1460742  ...  Chordata  Osteichthyes
# ...                                      ...  ...       ...           ...
# 168615  a98a2430-138f-11e2-bac6-74e5434f2f5c  ...  Chordata  Osteichthyes
# 168616                              32001123  ...  Chordata  Osteichthyes
# 168617                               1818536  ...  Chordata  Osteichthyes
# 168618  3053b070-1be4-11e1-9652-0022fbb9d9ae  ...  Chordata  Osteichthyes
# 168619                               1666316  ...  Chordata  Osteichthyes
#
#                family           genus  subgenus specificEpithet  \
# 0       Pomacentridae  Acanthochromis       NaN             NaN
# 1       Pomacentridae  Acanthochromis       NaN             NaN
# 2       Pomacentridae  Acanthochromis       NaN             NaN
# 3       Pomacentridae  Acanthochromis       NaN             NaN
# 4       Pomacentridae  Acanthochromis       NaN             NaN
# ...               ...             ...       ...             ...
# 168615   Acanthuridae       Zebrasoma       NaN             NaN
# 168616   Acanthuridae       Zebrasoma       NaN             NaN
# 168617      Siganidae         Siganus       NaN             NaN
# 168618      Zanclidae         Zanclus       NaN             NaN
# 168619   Acanthuridae       Zebrasoma       NaN             NaN
#
#         infraspecificEpithet  taxonRank scientificNameAuthorship  \
# 0                        NaN    species                      NaN
# 1                        NaN    species                      NaN
# 2                        NaN    species                      NaN
# 3                        NaN    species                      NaN
# 4                        NaN    species                      NaN
# ...                      ...        ...                      ...
# 168615                   NaN    species                      NaN
# 168616                   NaN    Species                      NaN
# 168617                   NaN    species                      NaN
# 168618                   NaN    Species                      NaN
# 168619                   NaN    Species                      NaN
#
#         vernacularName
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 168615             NaN
# 168616             NaN
# 168617             NaN
# 168618             NaN
# 168619             NaN
#
# [168620 rows x 66 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168620 entries, 0 to 168619
# Data columns (total 66 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             168620 non-null  object
#  1   modified                       168620 non-null  object
#  2   bibliographicCitation          0 non-null       float64
#  3   references                     0 non-null       float64
#  4   institutionCode                168620 non-null  object
#  5   collectionCode                 168620 non-null  object
#  6   basisOfRecord                  168620 non-null  object
#  7   materialSampleID               0 non-null       float64
#  8   occurrenceID                   168620 non-null  object
#  9   catalogNumber                  168620 non-null  object
#  10  occurrenceRemarks              0 non-null       float64
#  11  recordNumber                   0 non-null       float64
#  12  recordedBy                     0 non-null       float64
#  13  individualCount                0 non-null       float64
#  14  organismQuantity               168620 non-null  int64
#  15  organismQuantityType           168620 non-null  object
#  16  sex                            0 non-null       float64
#  17  lifeStage                      0 non-null       float64
#  18  occurrenceStatus               168620 non-null  object
#  19  preparations                   0 non-null       float64
#  20  otherCatalogNumbers            0 non-null       float64
#  21  associatedReferences           0 non-null       float64
#  22  organismID                     0 non-null       float64
#  23  associatedOccurrences          0 non-null       float64
#  24  eventID                        0 non-null       float64
#  25  samplingProtocol               0 non-null       float64
#  26  sampleSizeValue                0 non-null       float64
#  27  sampleSizeUnit                 0 non-null       float64
#  28  eventDate                      168620 non-null  datetime64[ns]
#  29  eventTime                      0 non-null       float64
#  30  year                           0 non-null       float64
#  31  month                          0 non-null       float64
#  32  verbatimEventDate              0 non-null       float64
#  33  fieldNumber                    0 non-null       float64
#  34  waterBody                      0 non-null       float64
#  35  country                        168620 non-null  object
#  36  stateProvince                  168620 non-null  object
#  37  county                         0 non-null       float64
#  38  locality                       0 non-null       float64
#  39  minimumDepthInMeters           168620 non-null  int64
#  40  maximumDepthInMeters           168620 non-null  int64
#  41  decimalLatitude                168620 non-null  float64
#  42  decimalLongitude               168620 non-null  float64
#  43  coordinateUncertaintyInMeters  168620 non-null  int64
#  44  coordinatePrecision            168620 non-null  float64
#  45  footprintWKT                   168620 non-null  object
#  46  identifiedBy                   0 non-null       float64
#  47  dateIdentified                 0 non-null       float64
#  48  identificationReferences       0 non-null       float64
#  49  identificationRemarks          0 non-null       float64
#  50  identificationQualifier        0 non-null       float64
#  51  typeStatus                     0 non-null       float64
#  52  scientificNameID               168620 non-null  object
#  53  taxonConceptID                 0 non-null       float64
#  54  scientificName                 168620 non-null  object
#  55  kingdom                        168620 non-null  object
#  56  phylum                         168620 non-null  object
#  57  class                          168620 non-null  object
#  58  family                         168620 non-null  object
#  59  genus                          168620 non-null  object
#  60  subgenus                       0 non-null       float64
#  61  specificEpithet                0 non-null       float64
#  62  infraspecificEpithet           0 non-null       float64
#  63  taxonRank                      159636 non-null  object
#  64  scientificNameAuthorship       0 non-null       float64
#  65  vernacularName                 1902 non-null    object
# dtypes: datetime64[ns](1), float64(40), int64(4), object(21)
# memory usage: 84.9+ MB

# %% [markdown]
# ## Dataset summary
# - **Rows:** 168,620
# - **Columns:** 66
# - **Date range:** 1992-03-28 to 2018-05-04
# - **Unique scientific names:** 253
# - **Unique families:** 11
# - **Unique genera:** 54
# - **Countries:** 1
# - **States/Provinces:** 1
# - **Latitude range:** -23.89088 to -14.52352
# - **Longitude range:** 145.35140 to 152.66857
# - **Summary generated:** 2026-05-26 (from local `AIMSdataset/occurrence.txt`)

# %% [markdown]
# ## Missingness

# %%
missingness = df.isna().mean().sort_values(ascending=False)
completely_missing = missingness[missingness == 1.0]
non_missing = missingness[missingness == 0.0]
some_missing = missingness[(missingness > 0.0) & (missingness < 1.0)]

print(f"Complete missingness: {len(completely_missing)} columns", completely_missing.index.tolist())
print(f"Non-missing: {len(non_missing)} columns", non_missing.index.tolist())
print(f"Some missing: {len(some_missing)} columns", some_missing.index.tolist())
# Out:
# Complete missingness: 37 columns ['references', 'bibliographicCitation', 'typeStatus', 'subgenus', 'materialSampleID', 'lifeStage', 'individualCount', 'recordedBy', 'recordNumber', 'occurrenceRemarks', 'sex', 'samplingProtocol', 'associatedOccurrences', 'eventID', 'organismID', 'associatedReferences', 'otherCatalogNumbers', 'preparations', 'verbatimEventDate', 'sampleSizeUnit', 'eventTime', 'year', 'fieldNumber', 'month', 'sampleSizeValue', 'specificEpithet', 'identificationQualifier', 'identificationReferences', 'dateIdentified', 'identifiedBy', 'identificationRemarks', 'locality', 'county', 'waterBody', 'taxonConceptID', 'infraspecificEpithet', 'scientificNameAuthorship']
# Non-missing: 27 columns ['id', 'modified', 'eventDate', 'catalogNumber', 'occurrenceStatus', 'basisOfRecord', 'collectionCode', 'institutionCode', 'occurrenceID', 'organismQuantityType', 'organismQuantity', 'decimalLongitude', 'coordinateUncertaintyInMeters', 'coordinatePrecision', 'footprintWKT', 'stateProvince', 'minimumDepthInMeters', 'maximumDepthInMeters', 'decimalLatitude', 'country', 'class', 'kingdom', 'scientificName', 'scientificNameID', 'phylum', 'family', 'genus']
# Some missing: 2 columns ['vernacularName', 'taxonRank']

# %% [markdown]
# ## Taxonomic coverage
#
# Top 10 scientific names by record count:
#
# | Scientific name | records |
# |---|---|
# | Pomacentrus lepidogenys | 3,364 |
# | Chlorurus sordidus | 3,359 |
# | Acanthochromis polyacanthus | 3,275 |
# | Scarus niger | 3,239 |
# | Hemigymnus fasciatus | 2,765 |
# | Plectropomus leopardus | 2,760 |
# | Pomacentrus wardi | 2,746 |
# | Chlorurus microrhinos | 2,725 |
# | Pomacentrus moluccensis | 2,710 |
# | Amblyglyphidodon curacao | 2,695 |
#
# Top 10 families by record count:
#
# | Family | records |
# |---|---|
# | Pomacentridae | 55,693 |
# | Scaridae | 33,410 |
# | Chaetodontidae | 25,026 |
# | Labridae | 16,654 |
# | Acanthuridae | 14,827 |
# | Siganidae | 7,677 |
# | Lutjanidae | 5,459 |
# | Serranidae | 5,076 |
# | Lethrinidae | 3,143 |
# | Zanclidae | 1,654 |

# %%
# Top species and families
(df['scientificName'].value_counts().head(10),
 df['family'].value_counts().head(10))
# Out:
# (scientificName
#  Pomacentrus lepidogenys        3364
#  Chlorurus sordidus             3359
#  Acanthochromis polyacanthus    3275
#  Scarus niger                   3239
#  Hemigymnus fasciatus           2765
#  Plectropomus leopardus         2760
#  Pomacentrus wardi              2746
#  Chlorurus microrhinos          2725
#  Pomacentrus moluccensis        2710
#  Amblyglyphidodon curacao       2695
#  Name: count, dtype: int64,
#  family
#  Pomacentridae     55693
#  Scaridae          33410
#  Chaetodontidae    25026
#  Labridae          16654
#  Acanthuridae      14827
#  Siganidae          7677
#  Lutjanidae         5459
#  Serranidae         5076
#  Lethrinidae        3143
#  Zanclidae          1654
#  Name: count, dtype: int64)

# %% [markdown]
# ## Temporal coverage
#
# Counts for earliest years:
#
# | Year | records |
# |---|---|
# | 1992 | 3,038 |
# | 1993 | 3,779 |
# | 1994 | 4,963 |
# | 1995 | 5,973 |
# | 1996 | 6,002 |
#
# Counts for latest years:
#
# | Year | records |
# |---|---|
# | 2014 | 5,570 |
# | 2015 | 6,584 |
# | 2016 | 7,664 |
# | 2017 | 5,422 |
# | 2018 | 5,213 |

# %%
# Yearly trend

year_counts = df['eventDate'].dt.year.value_counts().sort_index()
ax = year_counts.plot(kind='line', figsize=(8, 4), title='Records per year')
ax.set_xlabel('Year')
ax.set_ylabel('Records')
# Out:
# Text(0, 0.5, 'Records')

# %% [markdown]
# ## Spatial coverage
#
# The dataset spans the Great Barrier Reef region in Queensland, Australia. Use the plot below to visualize sampling locations.

# %%
# Spatial scatter (lat/long)
fig, ax = plt.subplots(figsize=(6, 5))
ax.scatter(df['decimalLongitude'], df['decimalLatitude'], s=4, alpha=0.2)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Sampling locations')
# Out:
# Text(0.5, 1.0, 'Sampling locations')

# %% [markdown]
# ## Blacktip reef shark check
#
# Check for **Carcharhinus melanopterus** (blacktip reef shark) and vernacular name 'blacktip reef shark'.

# %%
# Blacktip reef shark check
blacktip_scientific = 'Carcharhinus melanopterus'
blacktip_mask = df['scientificName'].str.contains(blacktip_scientific, case=False, na=False)
blacktip_common_mask = df['vernacularName'].str.contains('blacktip reef shark', case=False, na=False)

blacktip_rows = df[blacktip_mask | blacktip_common_mask]
print(f'Blacktip records found: {len(blacktip_rows)}')
print(f'Exists? {len(blacktip_rows) > 0}')
blacktip_rows[['eventDate', 'scientificName', 'vernacularName', 'decimalLatitude', 'decimalLongitude']].head()
# Out:
# Blacktip records found: 0
# Exists? False
# Empty DataFrame
# Columns: [eventDate, scientificName, vernacularName, decimalLatitude, decimalLongitude]
# Index: []
